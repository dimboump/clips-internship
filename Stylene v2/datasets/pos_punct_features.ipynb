# %%
import pandas as pd
import spacy

# %%
df_init = pd.read_csv('tokenized/blog_authorship_tokenized.csv').drop('n_words', axis=1)
df_init.sample(5)
# Out:
#                                                      text  gender horoscope  \
# 132436  It's 3:00 and I am bored at work, so why not p...  female     Aries
# 217103  As of late, I've been feeling like shit, parct...  female    Pisces
# 626553  No i've not been dead or in a coma or somin el...    male  Aquarius
# 80832   Too Early... i got to school ( UA&P ) too earl...    male     Aries
# 343573  " R adiohead is concise..Mars Volta tools alot...    male       Leo
#
#                job age_group  \
# 132436      indUnk     18-24
# 217103     Student       <18
# 626553     Student       <18
# 80832       indUnk     18-24
# 343573  Consulting     25-34
#
#                                                 tokenized
# 132436  it 's 3:00 and i am bored at work , so why not...
# 217103  as of late , i 've been feeling like shit , pa...
# 626553  no i 've not been dead or in a coma or somin e...
# 80832   too early ... i got to school ( ua&p ) too ear...
# 343573  " r adiohead is concise .. mars volta tools al...

# %%
nlp = spacy.load('en_core_web_md')

def get_pos_features(text):
    doc = nlp(text, disable=['parser', 'ner'])
    return " ".join([token.pos_ for token in doc])

# %%
df_init = df_init.assign(pos=df_init['text'].apply(get_pos_features))
df_init.sample(10)
# Out:
#                                                      text  gender  horoscope  \
# 369149  Het is de afgelope dagen echt verschrikkelijk ...    male      Aries
# 356104  So the couple I had slept with back during win...    male     Pisces
# 455831  Here at Toyah Creek, we consider it our missio...    male      Virgo
# 344621  finally got my PC back home and online... but ...  female     Cancer
# 285462  so athens may not be ready for the olympics, b...  female      Virgo
# 424628  I haven't posted in like a bagillion years. I'...    male      Virgo
# 440239  Just when youâre trying to forget someone, t...  female     Gemini
# 517168  Well, the back of the DVD didn't have a plot s...    male  Capricorn
# 249472  Hey! Look at my blog! it is different. woooooo...  female  Capricorn
# 542578  i'm uncomfortable. investigative reporting see...    male     Taurus
#
#                job age_group  \
# 369149  Non-Profit       <18
# 356104     Student     18-24
# 455831     Student     18-24
# 344621      indUnk     18-24
# 285462      indUnk     25-34
# 424628  Non-Profit       <18
# 440239     Student       <18
# 517168      indUnk       >35
# 249472  Non-Profit       <18
# 542578      indUnk     25-34
#
#                                                 tokenized  \
# 369149  het is de afgelope dagen echt verschrikkelijk ...
# 356104  so the couple i had slept with back during win...
# 455831  here at toyah creek , we consider it our missi...
# 344621  finally got my pc back home and online ... but...
# 285462  so athens may not be ready for the olympics , ...
# 424628  i have n't posted in like a bagillion years . ...
# 440239  just when youâre trying to forget someone , ...
# 517168  well , the back of the dvd did n't have a plot...
# 249472  hey ! look at my blog ! it is different . wooo...
# 542578  i 'm uncomfortable . investigative reporting s...
#
#                                                       pos
# 369149  PROPN AUX PROPN PROPN PROPN PROPN PROPN PROPN ...
# 356104  ADV DET NOUN PRON AUX VERB ADP ADV ADP NOUN VE...
# 455831  ADV ADP PROPN PROPN PUNCT PRON VERB PRON PRON ...
# 344621  ADV VERB PRON NOUN ADV ADV CCONJ ADV PUNCT CCO...
# 285462  ADV PROPN AUX PART AUX ADJ ADP DET NOUN PUNCT ...
# 424628  PRON AUX PART VERB ADP ADP DET NOUN NOUN PUNCT...
# 440239  ADV SCONJ VERB VERB PART VERB PRON PUNCT VERB ...
# 517168  INTJ PUNCT DET NOUN ADP DET NOUN AUX PART AUX ...
# 249472  INTJ PUNCT VERB ADP PRON NOUN PUNCT PRON AUX A...
# 542578  PRON AUX ADJ PUNCT ADJ NOUN VERB ADV ADJ ADP P...

# %%
from string import punctuation

def total_punct(text: str) -> int:
    return sum([1 for char in text if char in punctuation])

def punct_dist(text: str) -> float:
    return sum([1 for char in text if char in punctuation]) / len(text)

def count_punct(text: str) -> dict:
    return {char: text.count(char) for char in punctuation}

# %%
df = df_init.copy()
df = df.assign(
    total_punct=df_init['text'].apply(total_punct),
    punct_dist=df_init['text'].apply(punct_dist),
    count_punct=df_init['text'].apply(count_punct)
)
df.sample(10)
# Out:
#                                                      text  gender  horoscope  \
# 217067  Hello there. It is now Saturday, July 17 and I...  female     Gemini
# 166646  and another thing: "I need to finish this up,"...  female     Cancer
# 456355  Well, well... look who's starting an online bl...  female      Libra
# 231482  Allison: you really musn't bohter with the hyp...    male      Aries
# 377849  I sent an e-card to my ex this morning, to wis...  female        Leo
# 512953  "The best way to show our gratitude . . . is t...    male      Aries
# 375704  Divya, Dr Who is not a disease, it's a lifesty...  female  Capricorn
# 513210  "It is righteousness and not peace which shoul...    male      Aries
# 200209  I am so sick....lol THANKS ED. Although I have...  female   Aquarius
# 330219  I can not stand people! That is all...I am lea...  female     Cancer
#
#                job age_group  \
# 217067      indUnk     25-34
# 166646      indUnk     25-34
# 456355      indUnk       <18
# 231482  Consulting       <18
# 377849      indUnk     18-24
# 512953      indUnk     25-34
# 375704      indUnk       <18
# 513210      indUnk     25-34
# 200209     Student     25-34
# 330219        Arts     18-24
#
#                                                 tokenized  \
# 217067  hello there . it is now saturday , july 17 and...
# 166646  and another thing : " i need to finish this up...
# 456355  well , well ... look who 's starting an online...
# 231482  allison : you really musn't bohter with the hy...
# 377849  i sent an e - card to my ex this morning , to ...
# 512953  " the best way to show our gratitude . . . is ...
# 375704  divya , dr who is not a disease , it 's a life...
# 513210  " it is righteousness and not peace which shou...
# 200209  i am so sick .... lol thanks ed . although i h...
# 330219  i can not stand people ! that is all ... i am ...
#
#                                                       pos  total_punct  \
# 217067  INTJ ADV PUNCT PRON AUX ADV PROPN PUNCT PROPN ...           12
# 166646  CCONJ DET NOUN PUNCT PUNCT PRON VERB PART VERB...           35
# 456355  INTJ PUNCT INTJ PUNCT VERB PRON AUX VERB DET A...          100
# 231482  PROPN PUNCT PRON ADV VERB ADJ ADP DET NOUN PUN...          115
# 377849  PRON VERB DET NOUN NOUN NOUN ADP PRON NOUN DET...           48
# 512953  PUNCT DET ADJ NOUN PART VERB PRON NOUN PUNCT P...            8
# 375704  PROPN PUNCT PROPN PRON AUX PART DET NOUN PUNCT...           98
# 513210  PUNCT PRON AUX ADJ CCONJ PART NOUN DET AUX VER...            4
# 200209  PRON AUX ADV ADJ PUNCT INTJ PROPN PROPN PUNCT ...           25
# 330219  PRON AUX PART VERB NOUN PUNCT DET AUX DET PUNC...            5
#
#         punct_dist                                        count_punct
# 217067    0.085106  {'!': 5, '"': 0, '#': 0, '$': 0, '%': 0, '&': ...
# 166646    0.061837  {'!': 0, '"': 4, '#': 0, '$': 0, '%': 0, '&': ...
# 456355    0.079114  {'!': 1, '"': 0, '#': 0, '$': 0, '%': 0, '&': ...
# 231482    0.156889  {'!': 85, '"': 0, '#': 0, '$': 0, '%': 0, '&':...
# 377849    0.046693  {'!': 7, '"': 0, '#': 0, '$': 0, '%': 0, '&': ...
# 512953    0.086022  {'!': 0, '"': 2, '#': 0, '$': 0, '%': 0, '&': ...
# 375704    0.053059  {'!': 7, '"': 4, '#': 0, '$': 0, '%': 0, '&': ...
# 513210    0.016807  {'!': 0, '"': 2, '#': 0, '$': 0, '%': 0, '&': ...
# 200209    0.047348  {'!': 0, '"': 0, '#': 0, '$': 0, '%': 0, '&': ...
# 330219    0.064935  {'!': 1, '"': 0, '#': 0, '$': 0, '%': 0, '&': ...

# %%
df.to_csv('tokenized/blog_authorship_tokenized_pos_punct_final.csv', index=False)

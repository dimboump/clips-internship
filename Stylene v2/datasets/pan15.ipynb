# %%
import re
import glob
from lxml import etree
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
PAN15 = r'PAN15-training/'

pan15 = pd.DataFrame()

for file in glob.glob(PAN15 + '*.xml'):
    tree = etree.parse(file)
    root = tree.getroot()
    author = root.attrib['id']
    documents = [child.text for child in root.findall('document')]
    author_df = pd.DataFrame({'author': author, 'documents': documents})
    pan15 = pd.concat([pan15, author_df], ignore_index=True)

pan15.shape
# Out:
# (14166, 2)

# %%
pan15['author'] = LabelEncoder().fit_transform(pan15['author'])
pan15.sample(15)
# Out:
#        author                                          documents
# 11706     126                    @username Goodmorning boooo\t\t
# 10041     106        @username @username @username whattttt?\t\t
# 13756     147         Dreaming about the things we could be.\t\t
# 7752       82  @username Enjoy it! And rock the bass, the sex...
# 6143       65  99 Red Balloons - played with red balloons.: h...
# 6675       71                           Lkkr fout ohohcherso\t\t
# 4177       44  i really wanna shove their sticks up their ass...
# 13269     142  When people say really mean things to you.. ht...
# 3476       37  Gnip and Twitter Bringing Social Data to Acade...
# 418         4  @username Im going to see it on friday with my...
# 8446       89  free and open learning to kids in programming ...
# 7922       84                         A love song for no one\t\t
# 7667       81  RT @username: Research Brief: Big Data Pros an...
# 303         3     First-world anarchy http://t.co/6EVIumWNCH\t\t
# 12448     133  @username @username Ferdo sin coche. Según @us...

# %%
def clean_doc(doc):
    doc = doc.lower()
    doc = re.sub(r'@\w+', '', doc)
    doc = re.sub(r'([.,!?])\1+', r'\1', doc) # remove repeated punctuation
    doc = re.sub(r'http\S+', '', doc)
    doc = re.sub('\t', ' ', doc)
    doc = re.sub('\s+', ' ', doc)
    return doc

# %%
pan15['semicleaned'] = pan15['documents'].apply(clean_doc)
pan15.sample(15)
# Out:
#       author                                          documents  \
# 8117      86  ugg life is compilcated right now no time for ...
# 5657      60  #EnLaOficina #lvklabs (@username St. Andrews) ...
# 4094      43  twitturk.com sayfam: http://twitturk.com/twitu...
# 8869      93               Runaway train, never going back.\t\t
# 5141      54  lmaooo ???? “@username: Kids these days lol ??...
# 8455      89  Top Italian Investors Talk About Their Country...
# 1094      11  Pastry of Nike Air force halen? #dezezomer #wi...
# 6412      68  [Photo] tools #evolution http://t.co/Qarh77TH\t\t
# 8437      89  30 tips for avoiding #startup failure, from su...
# 6100      64  Bitch please! @username @username Mexsi Bocu h...
# 538        5  I'm so glad we invited a couple of Scots to #c...
# 7479      79  today is the one year anniversary of my Atlant...
# 2865      29  @username @username And what if it gets voided...
# 1737      17  The Master of Management Program keeps getting...
# 9386      98             mummy do me space in ur bed!! ????\t\t
#
#                                             semicleaned
# 8117  ugg life is compilcated right now no time for ...
# 5657              #enlaoficina #lvklabs ( st. andrews)
# 4094                              twitturk.com sayfam:
# 8869                  runaway train, never going back.
# 5141  lmaooo ? “: kids these days lol ? #aysiaysi #t...
# 8455  top italian investors talk about their country...
# 1094   pastry of nike air force halen? #dezezomer #wit
# 6412                          [photo] tools #evolution
# 8437  30 tips for avoiding #startup failure, from su...
# 6100                          bitch please! mexsi bocu
# 538   i'm so glad we invited a couple of scots to #c...
# 7479  today is the one year anniversary of my atlant...
# 2865   and what if it gets voided before you managed...
# 1737  the master of management program keeps getting...
# 9386                    mummy do me space in ur bed! ?

# %%
pan15.to_csv('pan15_semicleaned.csv', index=False)

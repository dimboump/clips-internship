# %%
import re
from glob import glob
from lxml import etree
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
pan15_docs = pd.DataFrame()

for file in glob('PAN15-training/*.xml'):
    tree = etree.parse(file)
    root = tree.getroot()
    author = root.attrib['id']
    documents = [child.text for child in root.findall('document')]
    author_df = pd.DataFrame({'author': author, 'documents': documents})
    pan15_docs = pd.concat([pan15_docs, author_df], ignore_index=True)

pan15_docs.shape
# Out:
# (14166, 2)

# %%
pan15_docs.head()
# Out:
#                                  author  \
# 0  02ae95de-7ee3-453a-978d-25d28b3f1a88
# 1  02ae95de-7ee3-453a-978d-25d28b3f1a88
# 2  02ae95de-7ee3-453a-978d-25d28b3f1a88
# 3  02ae95de-7ee3-453a-978d-25d28b3f1a88
# 4  02ae95de-7ee3-453a-978d-25d28b3f1a88
#
#                                            documents
# 0  Things I want for my business cards but are to...
# 1  "painters produced their most highly valued wo...
# 2  @username your new discussion layout is confus...
# 3  I never really understood why game environment...
# 4  @username 20k and 2048² on a gun, fine. But th...

# %%
pan15_docs.dtypes
# Out:
# author       object
# documents    object
# dtype: object

# %%
# Load labels
pan15_labels = pd.read_csv('PAN15-labels.txt', delimiter=':::', engine='python', header=None, names=['author', 'gender', 'age_group', '0', '1', '2', '3', '4'])
pan15_labels = pan15_labels[['author', 'gender', 'age_group']]
pan15_labels.shape
# Out:
# (152, 3)

# %%
pan15_labels.dtypes
# Out:
# author       object
# gender       object
# age_group    object
# dtype: object

# %%
pan15_docs.shape, pan15_labels.shape
# Out:
# ((14166, 2), (152, 3))

# %%
pan15_labels.sample(5)
# Out:
#                                    author gender age_group
# 128  c2253559-eb87-44ac-9a0b-a1d1a0cdfd48      F     18-24
# 70   5a3757da-1eda-4bb5-bf68-816fa10c2231      F     25-34
# 88   7f98ebb4-a2da-4579-9c3c-0f2fbaafc754      M     25-34
# 83   0b66092a-440e-4755-a624-759a580a1c70      F     25-34
# 95   c0f2ba6b-200e-44fb-ac60-81084eec9daa      M     18-24

# %%
pan15 = pd.merge(pan15_labels, pan15_docs, on=['author'])
pan15.shape
# Out:
# (14166, 4)

# %%
pan15.sample(10)
# Out:
#                                      author gender age_group  \
# 175    b38fee80-2fb1-4481-be25-e8297aae928d      M     25-34
# 13761  03f72f70-7a00-4dbb-93b7-6c7f65954fc5      M     25-34
# 10679  be1f9286-68c1-4864-b269-4b6de3b8b7eb      M     18-24
# 2297   703806e5-f04b-4e7c-8456-7340784ecf76      M     25-34
# 2248   703806e5-f04b-4e7c-8456-7340784ecf76      M     25-34
# 13080  e7d022a6-2292-4206-93f5-e63d3b0c3523      M     18-24
# 13384  78fb5696-dc1c-4ea9-b4e4-ae67acd7de72      F     25-34
# 13628  c7537d18-440b-451a-991a-22cb30f28d3a      F     50-XX
# 3087   675ce760-4be6-46ef-8190-2009f80fe283      F     18-24
# 13897  6919c68c-ce0f-47b7-a5f7-9e55eef6a557      F     25-34
#
#                                                documents
# 175                             Last 9 days. Tensed.\t\t
# 13761  R.I.P. Douglas Engelbart. Father of the Mother...
# 10679  Okayyyy so Asians can't handle booze @username...
# 2297   Kiss me in D.A.R.K. Tonight and love me when i...
# 2248   Para complementar mi springy look de pool part...
# 13080                               You look so cool\t\t
# 13384      Mornig buongiorno! Milano in grey  today!\t\t
# 13628                     @username  Heart-Breaker!!\t\t
# 3087   RT @username: Loyalty ain't shit these days I ...
# 13897  Typhoon Kalmaegi hits south China - http://t.c...

# %%
pan15['author'] = pan15['author'].apply(lambda x: x.split('-')[0]) # simplify author hash
pan15.sample(5)
# Out:
#          author gender age_group  \
# 4868   717b2dd5      M     25-34
# 4125   34e43885      M     25-34
# 13527  f3af2ca2      M     18-24
# 7119   fd7c89ad      F     18-24
# 1668   92defdbb      F     18-24
#
#                                                documents
# 4868   .@username #loveskiva (Tweet [your school name...
# 4125   Coursera Lands $43M From The World Bank, Yuri ...
# 13527  Fucked up\nInsecure\nNeurotic\nEmotional\n\nSo...
# 7119   I spy to change the world, to change your worl...
# 1668   I belong with you, you belong with me, you're ...

# %%
def clean(doc):
    doc = doc.lower()
    doc = re.sub(r'@\w+', '', doc) # remove @mentions
    doc = re.sub(r'#\w+', '', doc) # remove #hashtags
    doc = re.sub(r'http\S+', '', doc) # remove links
    doc = re.sub(r'([.,:!?])\1+', r'\1', doc) # remove repeated punctuation
    doc = re.sub('\t', ' ', doc)
    doc = re.sub('\s+', ' ', doc)
    return doc

# %%
pan15['semicleaned'] = pan15['documents'].apply(clean)
pan15.sample(15)
# Out:
#          author gender age_group  \
# 3416   a49c605b      M     35-49
# 13261  852149e1      F     25-34
# 4244   956f4dba      F     18-24
# 12065  88d5bfa3      F     25-34
# 14142  c4a413a1      F     25-34
# 3557   a6323e6d      F     25-34
# 1973   bb88ec91      F     18-24
# 8820   2298a7cc      F     35-49
# 9889   1661bc1b      F     35-49
# 12185  91c6d3f2      M     18-24
# 3277   bb414002      M     18-24
# 1111   97999fdb      F     18-24
# 7148   98ae4949      M     25-34
# 13100  e7d022a6      M     18-24
# 1738   2ae9cc17      F     25-34
#
#                                                documents  \
# 3416   "5 Unconventional Tips for Finding and Followi...
# 13261     3rd 9-hour workday in a row :( #sotired :(\t\t
# 4244   @username really wish youd notice me but we al...
# 12065  When Cesare attacks Juan at dinner. Just yes. ...
# 14142  Photo: Y en este Día Internacional del Hombre…...
# 3557   Unlikely reviewer @username analyzes @username...
# 1973   If you ain't happy with your life then you ain...
# 8820   Announcing the All-New St. Louis Observer http...
# 9889   @username: We met for a reason, either you're ...
# 12185  Oh they got me twisted they don't know that bo...
# 3277               Ain't no sunshine when she's gone\t\t
# 1111   Heartache doesn't last forever, I'll say I'm f...
# 7148   #Google introduces #Helpouts to connect people...
# 13100                                     New header\t\t
# 1738   @username you could cuddle with me instead :)\t\t
#
#                                              semicleaned
# 3416   "5 unconventional tips for finding and followi...
# 13261                 3rd 9-hour workday in a row :( :(
# 4244    really wish youd notice me but we all know th...
# 12065     when cesare attacks juan at dinner. just yes.
# 14142  photo: y en este día internacional del hombre…...
# 3557   unlikely reviewer analyzes 's farewell album '...
# 1973   if you ain't happy with your life then you ain...
# 8820          announcing the all-new st. louis observer
# 9889   : we met for a reason, either you're a blessin...
# 12185  oh they got me twisted they don't know that bo...
# 3277                  ain't no sunshine when she's gone
# 1111   heartache doesn't last forever, i'll say i'm f...
# 7148            introduces to connect people to experts
# 13100                                        new header
# 1738                you could cuddle with me instead :)

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

def tokenize(doc):
    return " ".join([token.lemma_ for token in nlp(doc)]).strip()

pan15['tokenized'] = pan15['semicleaned'].apply(tokenize)
pan15.sample(5)
# Out:
#          author gender age_group  \
# 8590   89fab4e9      F     35-49
# 6679   5a3757da      F     25-34
# 10331  d7f46166      F     50-XX
# 2269   703806e5      M     25-34
# 5701   3d50490f      F     25-34
#
#                                                documents  \
# 8590   Remembering Steven Yantis > Abrupt visual onse...
# 6679   I'm just gonna sit here and wish you missed me...
# 10331  @username  @username @username - Pockie and Ge...
# 2269   A handsome man for a cute ice cream. @username...
# 5701   My soundtrack: ? "Piove" by Jovanotti http://t...
#
#                                              semicleaned  \
# 8590   remembering steven yantis > abrupt visual onse...
# 6679   i'm just gonna sit here and wish you missed me...
# 10331   - pockie and george washington - - they canno...
# 2269   a handsome man for a cute ice cream. televisa ...
# 5701              my soundtrack: ? "piove" by jovanotti
#
#                                                   tokens
# 8590   remember steven yantis > abrupt visual onset a...
# 6679   I be just go to sit here and wish you miss I t...
# 10331  - pockie and george washington - - they can no...
# 2269   a handsome man for a cute ice cream . televisa...
# 5701            my soundtrack : ? " piove " by jovanotti

# %%
pan15.to_csv('pan15_semicleaned.tsv', sep='\t', index=False)

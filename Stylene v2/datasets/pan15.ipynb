# %%
import re
from glob import glob
from lxml import etree
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
pan15_docs = pd.DataFrame()

for file in glob('PAN15-training/*.xml'):
    tree = etree.parse(file)
    root = tree.getroot()
    author = root.attrib['id']
    documents = [child.text for child in root.findall('document')]
    author_df = pd.DataFrame({'author': author, 'documents': documents})
    pan15_docs = pd.concat([pan15_docs, author_df], ignore_index=True)

pan15_docs.shape
# Out:
# (14166, 2)

# %%
pan15_docs.head()
# Out:
#                                  author  \
# 0  02ae95de-7ee3-453a-978d-25d28b3f1a88
# 1  02ae95de-7ee3-453a-978d-25d28b3f1a88
# 2  02ae95de-7ee3-453a-978d-25d28b3f1a88
# 3  02ae95de-7ee3-453a-978d-25d28b3f1a88
# 4  02ae95de-7ee3-453a-978d-25d28b3f1a88
#
#                                            documents
# 0  Things I want for my business cards but are to...
# 1  "painters produced their most highly valued wo...
# 2  @username your new discussion layout is confus...
# 3  I never really understood why game environment...
# 4  @username 20k and 2048² on a gun, fine. But th...

# %%
pan15_docs.dtypes
# Out:
# author       object
# documents    object
# dtype: object

# %%
# Load labels
pan15_labels = pd.read_csv('PAN15-labels.txt', delimiter=':::', engine='python', header=None, names=['author', 'gender', 'age_group', 'extroverted', 'stable', 'agreeable', 'conscientious', 'open'])
pan15_labels.shape
# Out:
# (152, 8)

# %%
pan15_labels.dtypes
# Out:
# author            object
# gender            object
# age_group         object
# extroverted      float64
# stable           float64
# agreeable        float64
# conscientious    float64
# open             float64
# dtype: object

# %%
pan15_docs.shape, pan15_labels.shape
# Out:
# ((14166, 2), (152, 8))

# %%
pan15_labels.sample(5)
# Out:
#                                    author gender age_group  extroverted  \
# 127  25789f19-6181-492d-9f0d-d3b6d07fcc97      F     35-49          0.4
# 143  3aae4b14-7dfe-4cb7-b82a-629d01d06da0      F     25-34          0.0
# 133  17591594-b75c-47c2-be3e-5dcbe6c45286      M     25-34          0.2
# 136  7175696d-d60e-44ed-aebc-1f8582567995      M     25-34          0.1
# 84   61c4aca8-6e7f-4da3-9b30-1f99f7656189      M     25-34          0.1
#
#      stable  agreeable  conscientious  open
# 127     0.3        0.2            0.4   0.5
# 143     0.1        0.0            0.1   0.5
# 133     0.4        0.2            0.0   0.2
# 136     0.2        0.3            0.3   0.1
# 84      0.2        0.3            0.3   0.1

# %%
pan15 = pd.merge(pan15_labels, pan15_docs, on=['author'])
pan15.shape
# Out:
# (14166, 9)

# %%
pan15.sample(10)
# Out:
#                                      author gender age_group  extroverted  \
# 2375   f28ad171-3a6b-4f88-a3c9-feebe7b86747      F     35-49          0.4
# 13501  f3af2ca2-dbfb-4447-a4f2-dfdfdda58640      M     18-24          0.1
# 7470   3a396b48-d99c-4b22-9040-a50b6976f7cd      F     18-24          0.1
# 7394   f7ea5331-febf-4ed4-9416-7353c898ad35      M     25-34          0.1
# 6853   2b27ab92-c89d-4529-a238-905974a11cfd      M     25-34         -0.1
# 9014   c0f2ba6b-200e-44fb-ac60-81084eec9daa      M     18-24          0.1
# 6322   81584f97-1167-49e0-8da0-0d4d66f8e238      F     35-49          0.4
# 774    18695d44-ddf4-4839-9b00-d87b93f2d4ec      M     18-24          0.1
# 6318   81584f97-1167-49e0-8da0-0d4d66f8e238      F     35-49          0.4
# 8625   89fab4e9-24f0-4a97-8e10-ca357cc7865c      F     35-49          0.0
#
#        stable  agreeable  conscientious  open  \
# 2375      0.3        0.2            0.4   0.5
# 13501     0.2        0.3            0.1   0.2
# 7470     -0.3        0.2           -0.2   0.5
# 7394      0.3        0.2            0.3   0.0
# 6853      0.2        0.1            0.2   0.3
# 9014      0.4        0.0            0.1   0.2
# 6322      0.5        0.1            0.2   0.4
# 774      -0.1        0.2            0.0   0.2
# 6318      0.5        0.1            0.2   0.4
# 8625      0.3        0.5            0.4   0.2
#
#                                                documents
# 2375   Is Honey Boo Boo the Definition of an American...
# 13501     Free your mind, let your consious be free.\t\t
# 7470                 - Stand by me.\n- I will stand.\t\t
# 7394   Jolly Molly Jolly Molly Jolly Molly Jolly Moll...
# 6853   #LinkedIn Adds Trending Content List And A Sco...
# 9014   @username @username it was @username but now I...
# 6322   @username @username RT @username Do you know o...
# 774      "Hey yeah, dont let 'em know we're coming".\t\t
# 6318                       @username hipster camper!\t\t
# 8625   We the undersigned members of the European neu...

# %%
pan15['author'] = pan15['author'].apply(lambda x: x.split('-')[0]) # simplify author hash
pan15.sample(5)
# Out:
#          author gender age_group  extroverted  stable  agreeable  \
# 308    e78b60f0      F     18-24          0.1     0.1       -0.1
# 3793   3be30fbc      M     25-34          0.2     0.2        0.1
# 5681   3d50490f      F     25-34          0.2     0.1        0.2
# 12540  1d2a2248      F     50-XX         -0.2    -0.3       -0.1
# 12934  c657394c      F     35-49          0.4     0.5        0.1
#
#        conscientious  open                                          documents
# 308              0.5   0.1        "Don't take me the wrong way... But..."\t\t
# 3793             0.1   0.5  @username But today is not that day!! http://t...
# 5681             0.1   0.1  My soundtrack: ? "Anyone Else But You" by The ...
# 12540            0.0   0.5  @username  Oh No!!!!  Can you go back to dr?  ...
# 12934            0.2   0.4  @username tokrat bolj službene teme, machine t...

# %%
def clean(doc):
    doc = doc.lower()
    doc = re.sub(r'@\w+', '', doc) # remove @mentions
    doc = re.sub(r'#\w+', '', doc) # remove #hashtags
    doc = re.sub(r'http\S+', '', doc) # remove links
    doc = re.sub(r'([.,:!?])\1+', r'\1', doc) # remove repeated punctuation
    doc = re.sub('\d', '0', doc) # replace numbers with 0
    doc = re.sub('\s+', ' ', doc)
    return doc

# %%
pan15['semicleaned'] = pan15['documents'].apply(clean)
pan15.sample(15)
# Out:
#          author gender age_group  extroverted  stable  agreeable  \
# 5948   6c5201d6      M     25-34          0.2     0.4        0.2
# 4731   994c8615      M     25-34          0.1     0.4        0.1
# 4710   994c8615      M     25-34          0.1     0.4        0.1
# 8219   62bffe2f      M     50-XX          0.3    -0.1       -0.1
# 13153  b7bc6377      M     35-49          0.5    -0.1        0.2
# 5082   e2041e6d      F     25-34          0.3     0.2        0.2
# 10204  97432f40      M     35-49          0.2     0.2        0.1
# 10470  69ba7d3d      F     25-34          0.2     0.1        0.2
# 250    60468a75      M     18-24          0.1     0.2        0.1
# 7943   61c4aca8      M     25-34          0.1     0.2        0.3
# 6674   5a3757da      F     25-34          0.0    -0.2       -0.3
# 623    ed4bf592      M     18-24          0.1     0.2        0.3
# 5059   23842323      F     18-24          0.0    -0.1        0.1
# 6931   2b27ab92      M     25-34         -0.1     0.2        0.1
# 9420   a71c93ed      F     25-34          0.2     0.0        0.0
#
#        conscientious  open                                          documents  \
# 5948             0.1   0.4  @username Trying to contact #Nuance marketing ...
# 4731             0.0   0.4  [Neverhood OST] Southern Front Porch Whistler:...
# 4710             0.0   0.4  per me e` un si` - The Garden- What We Are htt...
# 8219             0.0  -0.1             @username ¿son *aplicaciones web*?\t\t
# 13153            0.2   0.5                 Got it? http://t.co/8OVyeeqn7N\t\t
# 5082             0.2   0.1  updating #iPad to #iOS6 and reading about new ...
# 10204            0.3   0.3  What You Should Know About the New Skype Trans...
# 10470            0.1   0.1  Sister in town @username #gift #vans #offthewa...
# 250              0.1   0.1  ''I entered into the bathroom and what happene...
# 7943             0.3   0.1  before the rain #milan #italy #afterlight #vsc...
# 6674             0.3   0.2  Almost put my stuff I'm the wrong grinder, who...
# 623              0.1   0.2                  Rare film maar wel super tof.\t\t
# 5059             0.3   0.4                                          Woosh\t\t
# 6931             0.2   0.3  #LaszloBock on Google's Approach to #HR: http:...
# 9420             0.3   0.4  Lol, sounds scary! @username: Please,anyone kn...
#
#                                              semicleaned
# 5948    trying to contact marketing office for academ...
# 4731   [neverhood ost] southern front porch whistler:...
# 4710     per me e` un si` - the garden- what we are via
# 8219                           ¿son *aplicaciones web*?
# 13153                                           got it?
# 5082   updating to and reading about new mobile healt...
# 10204  what you should know about the new skype trans...
# 10470                                  sister in town …
# 250    ''i entered into the bathroom and what happene...
# 7943               before the rain loreto (milan metro)
# 6674   almost put my stuff i'm the wrong grinder, who...
# 623                       rare film maar wel super tof.
# 5059                                              woosh
# 6931                          on google's approach to :
# 9420   lol, sounds scary! : please,anyone knows where...

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

def tokenize(doc):
    return " ".join([token.lemma_ for token in nlp(doc)])

pan15['tokenized'] = pan15['semicleaned'].apply(tokenize)
pan15.sample(5)
# Out:
#         author gender age_group  extroverted  stable  agreeable  \
# 7659  ed970294      M     18-24          0.1     0.2        0.2
# 430   f1dcc4ff      F     18-24          0.0    -0.1        0.1
# 2103  fde8eb00      F     25-34          0.3     0.2        0.2
# 1047  bde7a38f      F     25-34          0.0    -0.2       -0.3
# 4427  3f27d01d      M     35-49          0.1     0.1        0.1
#
#       conscientious  open                                          documents  \
# 7659            0.0   0.1  @username then what are you talking about ????...
# 430             0.3   0.4           So you think you can dance kijken (:\t\t
# 2103            0.2   0.1  Photo: Virtual Museum Showcases 130 Years Of N...
# 1047            0.3   0.2  Do what you will but please don't shut me out....
# 4427            0.1   0.1  Integrating @username in the middle would be g...
#
#                                             semicleaned  \
# 7659                 then what are you talking about ?
# 430               so you think you can dance kijken (:
# 2103  photo: virtual museum showcases 000 years of n...
# 1047    do what you will but please don't shut me out.
# 4427  integrating in the middle would be great!, 'in...
#
#                                               tokenized
# 7659                      then what be you talk about ?
# 430                so you think you can dance kijken (:
# 2103  photo : virtual museum showcase 000 year of nu...
# 1047    do what you will but please do not shut I out .
# 4427  integrate in the middle would be great ! , ' i...

# %%
def pos_fw(doc):
    return " ".join([token.pos_ if not token.is_stop and not token.is_punct else token.text for token in nlp(doc)])

# %%
pan15['pos_fw'] = pan15['tokenized'].apply(pos_fw)
pan15.head()
# Out:
#      author gender age_group  extroverted  stable  agreeable  conscientious  \
# 0  3e2cdc34      M     25-34          0.3     0.5        0.1            0.2
# 1  3e2cdc34      M     25-34          0.3     0.5        0.1            0.2
# 2  3e2cdc34      M     25-34          0.3     0.5        0.1            0.2
# 3  3e2cdc34      M     25-34          0.3     0.5        0.1            0.2
# 4  3e2cdc34      M     25-34          0.3     0.5        0.1            0.2
#
#    open                                          documents  \
# 0   0.2  How to Test Your Startup Idea for $50 http://t...
# 1   0.2  @username @username @username @username @usern...
# 2   0.2  New Story http://t.co/Uu5AggZP #storify #cacer...
# 3   0.2  @username @username @username @username You've...
# 4   0.2  @username @username @username @username @usern...
#
#                                     semicleaned  \
# 0        how to test your startup idea for $00
# 1   you've been quoted in my story "new story"
# 2                                    new story
# 3               you've been quoted in my story
# 4               you've been quoted in my story
#
#                                       tokenized  \
# 0        how to test your startup idea for $ 00
# 1    you 've be quote in my story " new story "
# 2                                     new story
# 3                  you 've be quote in my story
# 4                  you 've be quote in my story
#
#                                             pos_fw
# 0           how to VERB your NOUN NOUN for SYM NUM
# 1  SPACE you ' AUX be INTJ in my NOUN " ADJ NOUN "
# 2                                         ADJ NOUN
# 3               SPACE you ' AUX be INTJ in my NOUN
# 4               SPACE you ' AUX be INTJ in my NOUN

# %%
pan15.to_csv('pan15_semicleaned2.tsv', sep='\t', index=False)
